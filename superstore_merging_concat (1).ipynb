# %% [markdown]
# # 🛒 Superstore Sales: Merging, Concatenation, Pivoting & Melting
#
# This notebook demonstrates:
# - `pd.merge()` for joining tables
# - `pd.concat()` for stacking
# - `pivot_table()` and `melt()` for reshaping

# %% [markdown]
# ## 📥 Step 1: Load Superstore Dataset

# %%
import pandas as pd

# url = "https://raw.githubusercontent.com/nileshely/SuperStore-Dataset-2019-2022/main/superstore_dataset.csv"
#df = pd.read_csv(url)
#df.to_csv("superstore.csv") #save dataset from url to current working directory
df = pd.read_csv('superstore.csv')

print(df.columns)
df.head()
# Out:
# Index(['Unnamed: 0', 'order_id', 'order_date', 'ship_date', 'customer',
#        'manufactory', 'product_name', 'segment', 'category', 'subcategory',
#        'region', 'zip', 'city', 'state', 'country', 'discount', 'profit',
#        'quantity', 'sales', 'profit_margin'],
#       dtype='object')
#    Unnamed: 0        order_id order_date  ship_date       customer  \
# 0           0  US-2020-103800   1/3/2019   1/7/2019  Darren Powers
# 1           1  US-2020-112326   1/4/2019   1/8/2019  Phillina Ober
# 2           2  US-2020-112326   1/4/2019   1/8/2019  Phillina Ober
# 3           3  US-2020-112326   1/4/2019   1/8/2019  Phillina Ober
# 4           4  US-2020-141817   1/5/2019  1/12/2019     Mick Brown
#
#     manufactory                                       product_name  \
# 0  Message Book  Message Book, Wirebound, Four 5 1/2" X 4" Form...
# 1           GBC         GBC Standard Plastic Binding Systems Combs
# 2         Avery                                          Avery 508
# 3         SAFCO                      SAFCO Boltless Steel Shelving
# 4         Avery  Avery Hi-Liter EverBold Pen Style Fluorescent ...
#
#        segment         category subcategory   region    zip          city  \
# 0     Consumer  Office Supplies       Paper  Central  77095       Houston
# 1  Home Office  Office Supplies     Binders  Central  60540    Naperville
# 2  Home Office  Office Supplies      Labels  Central  60540    Naperville
# 3  Home Office  Office Supplies     Storage  Central  60540    Naperville
# 4     Consumer  Office Supplies         Art     East  19143  Philadelphia
#
#           state        country  discount   profit  quantity    sales  \
# 0         Texas  United States       0.2   5.5512         2   16.448
# 1      Illinois  United States       0.8  -5.4870         2    3.540
# 2      Illinois  United States       0.2   4.2717         3   11.784
# 3      Illinois  United States       0.2 -64.7748         3  272.736
# 4  Pennsylvania  United States       0.2   4.8840         3   19.536
#
#    profit_margin
# 0         0.3375
# 1        -1.5500
# 2         0.3625
# 3        -0.2375
# 4         0.2500

# %% [markdown]
# ## 🧱 Step 2: Create Tables for Merging
#
# To prepare for merge operations, we extract a few DataFrames:
#
# - orders_df: A deduplicated view of relevant order data, containing key   attributes like order ID, customer, sales, and region.
#
# - returns_df: A simulated dataset indicating returned orders. About 30% of unique order IDs are sampled and marked with a Returned = True column.
#
# - people_df: A fictional assignment of managers to each unique region. This prepares us for region-based enrichment of the order data.

# %%
orders_df = df[['order_id', 'order_date', 'customer', 'sales', 'region', 'segment']].drop_duplicates()

returns_df = pd.DataFrame({
    'order_id': df['order_id'].sample(frac=0.3, random_state=42).unique(),
    'Returned': True
})

print("Shape of the Returns_df")
print(returns_df.shape)

people_df = df[['region']].drop_duplicates().assign(Manager=['Alice', 'Bob', 'Clara', 'David'])
orders_df.head(), returns_df.head(), people_df.head()
# Out:
# Shape of the Returns_df
# (2266, 2)
# (         order_id order_date       customer    sales   region      segment
#  0  US-2020-103800   1/3/2019  Darren Powers   16.448  Central     Consumer
#  1  US-2020-112326   1/4/2019  Phillina Ober    3.540  Central  Home Office
#  2  US-2020-112326   1/4/2019  Phillina Ober   11.784  Central  Home Office
#  3  US-2020-112326   1/4/2019  Phillina Ober  272.736  Central  Home Office
#  4  US-2020-141817   1/5/2019     Mick Brown   19.536     East     Consumer,
#           order_id  Returned
#  0  US-2021-145849      True
#  1  US-2020-165764      True
#  2  US-2022-112669      True
#  3  US-2020-146591      True
#  4  US-2022-152800      True,
#      region Manager
#  0  Central   Alice
#  4     East     Bob
#  5    South   Clara
#  6     West   David)

# %% [markdown]
# ## 🔁 Step 3: Merge (Inner Join)
#
# ### Inner Merge
# An inner merge between orders_df and returns_df returns only the records with matching order_ids in both DataFrames. This helps us identify which specific orders were returned, excluding any unmatched entries. It’s commonly used when we want to work only with overlapping data.

# %%
merged_inner = pd.merge(orders_df, returns_df, on='order_id', how='inner')
merged_inner.head()


print(orders_df.shape, returns_df.shape, merged_inner.shape)
# Out:
# (9992, 6) (2266, 2) (5717, 7)

# %% [markdown]
# ## 🔄 Step 4: Merge (Left Join)
#
# ### Left Merge with Missing Value Handling
# The left merge includes all records from the orders(ie. the left table) and only the matching rows from returns. Orders without a return get a NaN in the Returned column. To make this binary and clean, we replace these missing values with False. This technique is useful when we want to preserve the full order list and flag returns where applicable.

# %%
merged_left = pd.merge(orders_df, returns_df, on='order_id', how='left')
merged_left['Returned'] = merged_left['Returned'].fillna(False)
merged_left.head()

print("shape of the merged left and the ordered df")
print(merged_left.shape, orders_df.shape)
# Out:
# shape of the merged left and the ordered df
# (9992, 7) (9992, 6)
# C:\Users\JOHN PAUL\AppData\Local\Temp\ipykernel_6784\848815336.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_left['Returned'] = merged_left['Returned'].fillna(False)

# %% [markdown]
# ## 🌐 Step 5: Merge (Outer Join)
#
# ### Outer Merge with Indicator
# An outer merge combines all rows from both DataFrames, whether they match or not. The special indicator=True argument adds a _merge column, showing whether each row came from the left (orders), right (returns), or both. This is ideal for comparing datasets or understanding overlap.

# %%
merged_outer = pd.merge(orders_df, returns_df, on='order_id', how='outer', indicator=True)
merged_outer.head(50)
# Out:
#           order_id  order_date            customer    sales   region  \
# 0   US-2020-100006    9/7/2019         Dennis Kane  377.970     East
# 1   US-2020-100090    7/8/2019          Ed Braxton  502.488     West
# 2   US-2020-100090    7/8/2019          Ed Braxton  196.704     West
# 3   US-2020-100279   3/10/2019    Scott Williamson   22.380  Central
# 4   US-2020-100293   3/14/2019    Neil Französisch   91.056    South
# 5   US-2020-100328   1/28/2019     Jasper Cacioppo    3.928     East
# 6   US-2020-100363    4/8/2019         Jim Mitchum    2.368     West
# 7   US-2020-100363    4/8/2019         Jim Mitchum   19.008     West
# 8   US-2020-100391   5/25/2019       Barry Weirich   14.620     East
# 9   US-2020-100678   4/18/2019        Kunst Miller  317.058  Central
# 10  US-2020-100678   4/18/2019        Kunst Miller    2.688  Central
# 11  US-2020-100678   4/18/2019        Kunst Miller  149.352  Central
# 12  US-2020-100678   4/18/2019        Kunst Miller  227.976  Central
# 13  US-2020-100706  12/16/2019     Laurel Elliston   29.460    South
# 14  US-2020-100706  12/16/2019     Laurel Elliston   99.980    South
# 15  US-2020-100762  11/24/2019          Nat Gilpin  151.920  Central
# 16  US-2020-100762  11/24/2019          Nat Gilpin  196.620  Central
# 17  US-2020-100762  11/24/2019          Nat Gilpin  144.120  Central
# 18  US-2020-100762  11/24/2019          Nat Gilpin   15.960  Central
# 19  US-2020-100853   9/14/2019    Jennifer Braxton   52.448  Central
# 20  US-2020-100853   9/14/2019    Jennifer Braxton   20.160  Central
# 21  US-2020-100860   3/26/2019       Cindy Stewart   18.750     West
# 22  US-2020-100867  10/19/2019   Eugene Hildebrand  321.552     West
# 23  US-2020-100881   3/28/2019       Daniel Raglin  302.376     West
# 24  US-2020-100895    6/2/2019    Stewart Visinsky    8.560    South
# 25  US-2020-100895    6/2/2019    Stewart Visinsky  356.940    South
# 26  US-2020-100895    6/2/2019    Stewart Visinsky  239.970    South
# 27  US-2020-100916  10/21/2019        Frank Hawley  591.320    South
# 28  US-2020-100916  10/21/2019        Frank Hawley    2.840    South
# 29  US-2020-100916  10/21/2019        Frank Hawley  194.700    South
# 30  US-2020-100972  11/19/2019       Dennis Bolton  166.440     West
# 31  US-2020-101147   12/2/2019        Matt Collins    2.394  Central
# 32  US-2020-101175   12/9/2019        Dario Medina  100.704     West
# 33  US-2020-101266   8/27/2019       Michael Moore   13.360    South
# 34  US-2020-101364  12/22/2019   Tamara Willingham  296.712     East
# 35  US-2020-101392   12/7/2019          Ann Steele  269.360     West
# 36  US-2020-101427  12/26/2019          Andy Yotov    8.016     East
# 37  US-2020-101462   4/20/2019  Benjamin Patterson   59.920     West
# 38  US-2020-101476   9/12/2019     Shirley Daniels   69.990     East
# 39  US-2020-101560  11/28/2019     Chris Selesnick  397.600    South
# 40  US-2020-101560  11/28/2019     Chris Selesnick   13.120    South
# 41  US-2020-101560  11/28/2019     Chris Selesnick   45.660    South
# 42  US-2020-101560  11/28/2019     Chris Selesnick   85.960    South
# 43  US-2020-101602  12/15/2019       Mick Crebagga  763.280  Central
# 44  US-2020-101602  12/15/2019       Mick Crebagga   40.680  Central
# 45  US-2020-101770   3/31/2019          Karen Bern    1.869    South
# 46  US-2020-101833  11/17/2019     Frank Gastineau   34.440     East
# 47  US-2020-101931  10/28/2019        Todd Sumrall  616.998     West
# 48  US-2020-101931  10/28/2019        Todd Sumrall    7.184     West
# 49  US-2020-101931  10/28/2019        Todd Sumrall  141.400     West
#
#         segment Returned     _merge
# 0      Consumer      NaN  left_only
# 1     Corporate      NaN  left_only
# 2     Corporate      NaN  left_only
# 3      Consumer      NaN  left_only
# 4   Home Office      NaN  left_only
# 5      Consumer      NaN  left_only
# 6     Corporate     True       both
# 7     Corporate     True       both
# 8      Consumer     True       both
# 9      Consumer     True       both
# 10     Consumer     True       both
# 11     Consumer     True       both
# 12     Consumer     True       both
# 13     Consumer      NaN  left_only
# 14     Consumer      NaN  left_only
# 15    Corporate     True       both
# 16    Corporate     True       both
# 17    Corporate     True       both
# 18    Corporate     True       both
# 19    Corporate     True       both
# 20    Corporate     True       both
# 21     Consumer     True       both
# 22  Home Office      NaN  left_only
# 23  Home Office     True       both
# 24     Consumer     True       both
# 25     Consumer     True       both
# 26     Consumer     True       both
# 27    Corporate      NaN  left_only
# 28    Corporate      NaN  left_only
# 29    Corporate      NaN  left_only
# 30  Home Office      NaN  left_only
# 31     Consumer      NaN  left_only
# 32    Corporate      NaN  left_only
# 33     Consumer      NaN  left_only
# 34  Home Office      NaN  left_only
# 35  Home Office      NaN  left_only
# 36    Corporate      NaN  left_only
# 37     Consumer      NaN  left_only
# 38  Home Office     True       both
# 39    Corporate      NaN  left_only
# 40    Corporate      NaN  left_only
# 41    Corporate      NaN  left_only
# 42    Corporate      NaN  left_only
# 43     Consumer     True       both
# 44     Consumer     True       both
# 45    Corporate      NaN  left_only
# 46  Home Office      NaN  left_only
# 47    Corporate     True       both
# 48    Corporate     True       both
# 49    Corporate     True       both

# %% [markdown]
# ## 📊 Step 6: Concatenation (Vertical Stack)
#
# ### Concatenation (Vertical Stacking)
# We split the orders_df into two halves using sample() and drop(), and then stack them back together using pd.concat(). This is a simple demonstration of combining datasets vertically—useful when appending rows from different periods, sources, or files with the same schema.

# %%
q1 = orders_df.sample(frac=0.5, random_state=1)
q2 = orders_df.drop(q1.index)
vertical_stack = pd.concat([q1, q2], axis=0)
vertical_stack.head(50)

# print(q1.shape, q2.shape)
# Out:
#             order_id  order_date            customer     sales   region  \
# 1816  US-2020-116568  12/14/2019         Bryan Mills   186.304    South
# 883   US-2020-109897   8/12/2019         Ben Wallace   806.336     West
# 1124  US-2020-106992   9/19/2019        Sean Braxton  3059.982  Central
# 6397  US-2022-109722   12/5/2021    Theone Pippenger   699.980    South
# 2913  US-2021-128090   8/16/2020         John Murray     2.304     West
# 6607  US-2022-157868  12/23/2021      Matt Collister    24.850  Central
# 3061  US-2021-117772   9/10/2020        Matt Collins   353.880     West
# 3835  US-2021-114741   12/6/2020         Ivan Liston  1325.850     West
# 278   US-2020-128055   3/31/2019          Alex Avila   673.568     West
# 915   US-2020-114321   8/20/2019       Nick Crebassa   896.990    South
# 3221  US-2021-153381   9/24/2020          Deanra Eno  1408.100  Central
# 8147  US-2023-100433   8/11/2022       Sanjit Jacobs    25.920     East
# 5432  US-2022-116540    9/2/2021        Sonia Sunley     8.260  Central
# 6909  US-2023-134838   2/19/2022        Emily Ducich    44.670     West
# 8467  US-2023-168403    9/9/2022     Damala Kotsonis    11.176     West
# 4942  US-2022-145842   6/17/2021         Fred McMath    40.740     East
# 7200  US-2023-131156    4/3/2022    Katherine Hughes    25.472     East
# 7834  US-2023-138310   6/26/2022          Nora Preis   431.928     West
# 3044  US-2021-102876    9/7/2020           Lisa Ryan     9.522     East
# 9839  US-2023-140585  12/18/2022   Russell Applegate   119.980     West
# 5595  US-2022-105732   9/13/2021     Alejandro Grove    17.610  Central
# 806   US-2020-169019   7/26/2019         Luke Foster    16.784  Central
# 3113  US-2021-100734   9/15/2020           Ann Chong   147.184     East
# 6967  US-2023-142174    3/4/2022       Darren Powers    89.568  Central
# 274   US-2020-104759   3/31/2019   Dorothy Dickinson     8.134  Central
# 5583  US-2022-128811   9/12/2021        Sarah Foster    11.070     West
# 8071  US-2023-101483   7/29/2022         Anna Gayman    34.848    South
# 9736  US-2023-140907  12/10/2022        Ben Peterman    18.240     West
# 8131  US-2023-155999    8/7/2022          Jay Kimmel    13.760     West
# 6205  US-2022-110772  11/20/2021       Nick Zandusky    18.496     East
# 4034  US-2021-111780  12/25/2020        Ralph Arnett    12.600     West
# 7526  US-2023-159464   5/18/2022          Todd Boyes   302.940    South
# 2753  US-2021-142237   7/11/2020        Clytie Kelty    25.344     East
# 6875  US-2023-131828   2/11/2022          Cari Sayre    88.776     West
# 860   US-2020-131450    8/8/2019        Lena Radford   327.760     West
# 1900  US-2020-154158  12/23/2019      Craig Carreira   424.272    South
# 6549  US-2022-112697  12/18/2021         Alan Haines   194.528    South
# 861   US-2020-131450    8/8/2019        Lena Radford    76.120     West
# 6194  US-2022-164511  11/19/2021         Doug Jacobs    64.960     East
# 4153  US-2022-148208   1/22/2021     Bradley Talbott    55.176     East
# 8471  US-2023-110905   9/10/2022      Robert Waldorf    24.180  Central
# 4608  US-2022-104311    5/2/2021  Adam Shillingsburg    12.672  Central
# 8506  US-2023-160836   9/11/2022       Cindy Chapman   512.190  Central
# 1290  US-2020-126571  10/11/2019          Jill Fjeld   201.432     East
# 6484  US-2022-160745  12/11/2021      Anthony Rawles    14.800     West
# 9478  US-2023-135307  11/26/2022          Lynn Smith   126.300  Central
# 1227  US-2020-146969   9/29/2019      Arthur Prichep   204.600     West
# 6890  US-2023-163265   2/16/2022           Joy Smith    18.368  Central
# 1340  US-2020-155264  10/19/2019        Rachel Payne    18.750     West
# 6632  US-2022-148684  12/25/2021       Trudy Schmidt   106.320    South
#
#           segment
# 1816     Consumer
# 883      Consumer
# 1124    Corporate
# 6397     Consumer
# 2913     Consumer
# 6607    Corporate
# 3061     Consumer
# 3835     Consumer
# 278      Consumer
# 915     Corporate
# 3221  Home Office
# 8147  Home Office
# 5432     Consumer
# 6909  Home Office
# 8467    Corporate
# 4942     Consumer
# 7200     Consumer
# 7834     Consumer
# 3044    Corporate
# 9839     Consumer
# 5595     Consumer
# 806      Consumer
# 3113    Corporate
# 6967     Consumer
# 274      Consumer
# 5583     Consumer
# 8071     Consumer
# 9736    Corporate
# 8131     Consumer
# 6205  Home Office
# 4034     Consumer
# 7526    Corporate
# 2753     Consumer
# 6875    Corporate
# 860      Consumer
# 1900     Consumer
# 6549    Corporate
# 861      Consumer
# 6194     Consumer
# 4153  Home Office
# 8471     Consumer
# 4608     Consumer
# 8506     Consumer
# 1290     Consumer
# 6484    Corporate
# 9478     Consumer
# 1227     Consumer
# 6890     Consumer
# 1340    Corporate
# 6632     Consumer

# %% [markdown]
# ## ➕ Step 7: Concatenation (Horizontal Stack)
#
# ### Merging with People (Managers)
# We enrich orders_df by merging it with people_df, using the common region column. This brings in manager information per region, useful for reporting, accountability, or filtering. It illustrates how merging can add descriptive attributes to transactional data.

# %%
orders_plus_manager = pd.merge(orders_df, people_df, on='region', how='left')
orders_plus_manager.head(40)
# Out:
#           order_id order_date           customer     sales   region  \
# 0   US-2020-103800   1/3/2019      Darren Powers    16.448  Central
# 1   US-2020-112326   1/4/2019      Phillina Ober     3.540  Central
# 2   US-2020-112326   1/4/2019      Phillina Ober    11.784  Central
# 3   US-2020-112326   1/4/2019      Phillina Ober   272.736  Central
# 4   US-2020-141817   1/5/2019         Mick Brown    19.536     East
# 5   US-2020-106054   1/6/2019      Jack O'Briant    12.780    South
# 6   US-2020-130813   1/6/2019   Lycoris Saunders    19.440     West
# 7   US-2020-167199   1/6/2019      Maria Etezadi  2573.820    South
# 8   US-2020-167199   1/6/2019      Maria Etezadi     5.480    South
# 9   US-2020-167199   1/6/2019      Maria Etezadi   609.980    South
# 10  US-2020-167199   1/6/2019      Maria Etezadi    31.120    South
# 11  US-2020-167199   1/6/2019      Maria Etezadi     6.540    South
# 12  US-2020-167199   1/6/2019      Maria Etezadi   755.960    South
# 13  US-2020-167199   1/6/2019      Maria Etezadi   391.980    South
# 14  US-2020-105417   1/7/2019   Vivek Sundaresam    76.728  Central
# 15  US-2020-105417   1/7/2019   Vivek Sundaresam    10.430  Central
# 16  US-2020-135405   1/9/2019      Melanie Seite     9.344  Central
# 17  US-2020-135405   1/9/2019      Melanie Seite    31.200  Central
# 18  US-2020-149020  1/10/2019     Anthony Jacobs    51.940    South
# 19  US-2020-149020  1/10/2019     Anthony Jacobs     2.890    South
# 20  US-2020-130092  1/11/2019        Seth Vernon     9.940     East
# 21  US-2020-109232  1/13/2019  Natalie DeCherney   545.940    South
# 22  US-2020-118192  1/13/2019      Michael Moore     3.438     East
# 23  US-2020-118192  1/13/2019      Michael Moore    37.408     East
# 24  US-2020-157147  1/13/2019       Brian Dahlen   333.999     West
# 25  US-2020-157147  1/13/2019       Brian Dahlen    19.900     West
# 26  US-2020-157147  1/13/2019       Brian Dahlen  1325.850     West
# 27  US-2020-162775  1/13/2019    Chris Selesnick     5.640    South
# 28  US-2020-162775  1/13/2019    Chris Selesnick    50.940    South
# 29  US-2020-162775  1/13/2019    Chris Selesnick    11.360    South
# 30  US-2020-162775  1/13/2019    Chris Selesnick   572.580    South
# 31  US-2020-162775  1/13/2019    Chris Selesnick   646.740    South
# 32  US-2020-149524  1/14/2019      Brendan Sweed    61.960     East
# 33  US-2020-103366  1/15/2019      Erica Hackney   149.950    South
# 34  US-2020-115791  1/16/2019  Delfina Latchford   127.104     East
# 35  US-2020-115791  1/16/2019  Delfina Latchford    18.588     East
# 36  US-2020-115791  1/16/2019  Delfina Latchford    30.072     East
# 37  US-2020-115791  1/16/2019  Delfina Latchford   124.200     East
# 38  US-2020-123477  1/18/2019       David Wiener    64.864     West
# 39  US-2020-146591  1/19/2019      Toby Swindell   181.470     West
#
#         segment Manager
# 0      Consumer   Alice
# 1   Home Office   Alice
# 2   Home Office   Alice
# 3   Home Office   Alice
# 4      Consumer     Bob
# 5     Corporate   Clara
# 6      Consumer   David
# 7   Home Office   Clara
# 8   Home Office   Clara
# 9   Home Office   Clara
# 10  Home Office   Clara
# 11  Home Office   Clara
# 12  Home Office   Clara
# 13  Home Office   Clara
# 14     Consumer   Alice
# 15     Consumer   Alice
# 16     Consumer   Alice
# 17     Consumer   Alice
# 18    Corporate   Clara
# 19    Corporate   Clara
# 20     Consumer     Bob
# 21     Consumer   Clara
# 22     Consumer     Bob
# 23     Consumer     Bob
# 24     Consumer   David
# 25     Consumer   David
# 26     Consumer   David
# 27    Corporate   Clara
# 28    Corporate   Clara
# 29    Corporate   Clara
# 30    Corporate   Clara
# 31    Corporate   Clara
# 32    Corporate     Bob
# 33     Consumer   Clara
# 34     Consumer     Bob
# 35     Consumer     Bob
# 36     Consumer     Bob
# 37     Consumer     Bob
# 38    Corporate   David
# 39     Consumer   David

# %% [markdown]
# ## 🔄 Step 8: Pivoting and Melting DataFrames
#
# ### Pivot Table: Sales by Region and Segment
# Pivot tables allow you to summarize your data across dimensions. Here, we use region as the row index and segment as columns to aggregate sales via sum. This is useful for comparing performance across different segments and regions in a clean table format.

# %%
pivot = df.pivot_table(index='region', columns='segment', values='sales', aggfunc='sum')
pivot
# Out:
# segment    Consumer    Corporate  Home Office
# region
# Central  252031.434  157995.8128   91212.6440
# East     350908.167  200409.3470  127463.7260
# South    195580.971  121885.9325   74255.0015
# West     362880.773  225855.2745  136721.7770

# %% [markdown]
# ### 🧭 Navigating MultiIndex
#
# ### Multi-Index Pivot Table
# This pivot table uses two index levels—region and category—and summarizes sales. It’s ideal for hierarchical reporting, where you want to break down data into sub-groups. This structure helps in identifying trends and performance within both broad and specific categories.

# %%
multi = df.pivot_table(index=['region', 'category'], values='sales', aggfunc='sum')
multi.head(50)
# Out:
#                                sales
# region  category
# Central Furniture        163797.1638
#         Office Supplies  167026.4150
#         Technology       170416.3120
# East    Furniture        208291.2040
#         Office Supplies  205516.0550
#         Technology       264973.9810
# South   Furniture        117298.6840
#         Office Supplies  125651.3130
#         Technology       148771.9080
# West    Furniture        252612.7435
#         Office Supplies  220853.2490
#         Technology       251991.8320

# %% [markdown]
# ## 🧯 Step 9: Melting DataFrames
#
# ### Melting DataFrames (Unpivoting)
# The melt() function is used to transform a wide DataFrame into a long one, often called “unpivoting.” In this case, the pivot table showing sales by region and segment is first reset using .reset_index() to turn the index (region) back into a column. Then, melt() is applied to convert the wide-format columns (Consumer, Corporate, etc.) into two columns: one for the variable name (segment) and another for the values (sales). This format is more suitable for plotting or further analysis, as it aligns with tidy data principles—where each row is a single observation.

# %%
melted = pivot.reset_index().melt(id_vars='region', var_name='segment', value_name='sales')
melted.head()
# Out:
#     region    segment        sales
# 0  Central   Consumer  252031.4340
# 1     East   Consumer  350908.1670
# 2    South   Consumer  195580.9710
# 3     West   Consumer  362880.7730
# 4  Central  Corporate  157995.8128

# %% [markdown]
# ## ✅ Summary of All Concepts

# %% [markdown]
# We practiced:
# - `pd.merge()` for relational joins
# - `pd.concat()` for stacking DataFrames
# - `pivot_table()` for summarized, multi-index views
# - `melt()` for reversing wide-to-long format
#
# These techniques reshape and organize your data for insights and presentation.
